# %% [markdown]
# # Improve Me
#
# When I was a student, I wrote this beautiful piece of code. It does not work. Help me improve it.
#
# Tip: use the instructions from [the ML4ME appendix](https://ideal.umd.edu/ML4ME_Textbook/appendices/helpful_tooling.html).
#
# ## Imports
#
# You can add your own extra imports if you need.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## Data Generation and Processing

# %% [markdown]
# ### Context
# Imagine a factory producing metal plates for some engineering application.
#
# Each plate is supposed to have uniform properties, but in reality, manufacturing imperfections (slightly thinner material, internal stresses, micro-defects) can cause some parts of a plate to bend more than others when pressure is applied.
#
# Quality control wants to measure deflection at every point `(x, y)` of the plate. This requires physical experiments and is slow and expensive. That's why we're building an ML model that is able to predict deflection `z` at any `(x, y)` point.
#
# We don't have exact measures so we will construct an artificial dataset where the deflection is actually not uniform on one side (the plate has a thinner corner).

# %%
# Our physical model

def generate_plate_data(n_samples: int = 100, n_plates: int = 5, noise_level: float = 0.2):
    """Generates multiple plates with a defect.

    Args:
        n_samples: number of points per plate
        n_plates: number of plates
        noise_level: noise level in the deflection

    Returns:
        X: input points
        y: deflection
    """
    n_sample_per_side = int(n_samples**0.5)
    x = torch.linspace(-2, 2, n_sample_per_side)
    y = torch.linspace(-2, 2, n_sample_per_side)
    xx, yy = torch.meshgrid(x, y, indexing="ij")
    X_base = torch.stack([xx.flatten(), yy.flatten()], dim=1)

    # Base deflection
    r2 = X_base[:,0]**2 + X_base[:,1]**2
    Z_base = torch.tanh(r2 / 5.0) * 5.0

    # Mask for the top-right corner defect
    corner_mask = (X_base[:,0] > 1.0) & (X_base[:,1] > 0.5)
    # Aggressive corner defect with y-dependent variation
    Z_base[corner_mask] *= 1 + 2*((X_base[corner_mask,0]-1.0)**2 + (X_base[corner_mask,1]-0.5)**2)
    

    # Replicate experiments with noise for different plates
    X_list, y_list = [], []  # noqa: N806
    for _ in range(n_plates):
        Z_noisy = Z_base + noise_level * torch.randn_like(Z_base)  # noqa: N806
        X_list.append(X_base)
        y_list.append(Z_noisy)

    # assemble the data
    X = torch.cat(X_list, dim=0)  # noqa: N806
    y = torch.cat(y_list, dim=0)
    idx = torch.argsort(X[:,0])
    X = X[idx]  # noqa: N806
    y = y[idx]

    return X, y

# %%
from sklearn.model_selection import train_test_split

# Generate full dataset
X_all, y_all = generate_plate_data(n_samples=100, n_plates=5, noise_level=0.4)
total_samples = X_all.shape[0]

fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(X_all[:,0], X_all[:,1], y_all, c="blue", alpha=0.3)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("deflection z")
ax.set_title("Plate deflection")
plt.show()

X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=42)

# %%
# Data preprocessing
x_scaler = StandardScaler()
y_scaler = StandardScaler()

# Normalizing our data, don't forget to unnormalize the predictions later!
X_train_scaled = torch.from_numpy(x_scaler.fit_transform(X_train.numpy())).float()
X_test_scaled = torch.from_numpy(x_scaler.transform(X_test.numpy())).float()
y_train_scaled = torch.from_numpy(y_scaler.fit_transform(y_train.numpy().reshape(-1, 1))).float().squeeze()
y_test_scaled = torch.from_numpy(y_scaler.transform(y_test.numpy().reshape(-1, 1))).float().squeeze()

# %% [markdown]
# ## Model definition

# %%
# Model definition
class NetleF(nn.Module):
    """A very efficient neural network for the given task, probably the best for the job."""
    def __init__(self):
        super().__init__()
        layers = []
        layers.append(nn.Linear(2, 20)) # input layer
        for _ in range(8):
            layers.append(nn.Sigmoid()) # activation function
            layers.append(nn.Linear(20, 20)) # hidden layer
        layers.append(nn.Sigmoid()) # activation function
        layers.append(nn.Linear(20, 1)) # output layer
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ## Training

# %%
model = NetleF()  # create model first
optimizer = optim.AdamW(model.parameters(), lr=1e-2, weight_decay=1e-3)
loss_fn = nn.MSELoss()

for epoch in range(500):
    model.train()
    y_pred_scaled = model(X_train_scaled).view(-1)  # safer than squeeze()
    loss = loss_fn(y_pred_scaled, y_train_scaled)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 5 == 0:
        model.eval()
        with torch.no_grad():
            test_pred_scaled = model(X_test_scaled).view(-1)
            test_loss = loss_fn(test_pred_scaled, y_test_scaled)
        print(f"Epoch {epoch:3d} | Train loss: {loss.item():.4f} | Test loss: {test_loss.item():.4f}")
# Out:
# Epoch   0 | Train loss: 1.0034 | Test loss: 0.1709
# Epoch   5 | Train loss: 1.0054 | Test loss: 0.2113
# Epoch  10 | Train loss: 1.0020 | Test loss: 0.1960
# Epoch  15 | Train loss: 1.0013 | Test loss: 0.2052
# Epoch  20 | Train loss: 1.0009 | Test loss: 0.1953
# Epoch  25 | Train loss: 1.0006 | Test loss: 0.2057
# Epoch  30 | Train loss: 1.0004 | Test loss: 0.1959
# Epoch  35 | Train loss: 1.0002 | Test loss: 0.2041
# Epoch  40 | Train loss: 1.0001 | Test loss: 0.1976
# Epoch  45 | Train loss: 1.0001 | Test loss: 0.2021
# Epoch  50 | Train loss: 1.0000 | Test loss: 0.1993
# Epoch  55 | Train loss: 0.9999 | Test loss: 0.2004
# Epoch  60 | Train loss: 0.9990 | Test loss: 0.2000
# Epoch  65 | Train loss: 0.9916 | Test loss: 0.1940
# Epoch  70 | Train loss: 0.9369 | Test loss: 0.1657
# Epoch  75 | Train loss: 0.7091 | Test loss: 0.0899
# Epoch  80 | Train loss: 0.3603 | Test loss: 0.0890
# Epoch  85 | Train loss: 0.3667 | Test loss: 0.3365
# Epoch  90 | Train loss: 0.4123 | Test loss: 0.3798
# Epoch  95 | Train loss: 0.2610 | Test loss: 0.0773
# Epoch 100 | Train loss: 0.2326 | Test loss: 0.0982
# Epoch 105 | Train loss: 0.2211 | Test loss: 0.1048
# Epoch 110 | Train loss: 0.2037 | Test loss: 0.1136
# Epoch 115 | Train loss: 0.1948 | Test loss: 0.1334
# Epoch 120 | Train loss: 0.1953 | Test loss: 0.1385
# Epoch 125 | Train loss: 0.1954 | Test loss: 0.1780
# Epoch 130 | Train loss: 0.3568 | Test loss: 0.1841
# Epoch 135 | Train loss: 0.3476 | Test loss: 0.1686
# Epoch 140 | Train loss: 0.3451 | Test loss: 0.1683
# Epoch 145 | Train loss: 0.3445 | Test loss: 0.1703
# Epoch 150 | Train loss: 0.3440 | Test loss: 0.1684
# Epoch 155 | Train loss: 0.3430 | Test loss: 0.1706
# Epoch 160 | Train loss: 0.3420 | Test loss: 0.1678
# Epoch 165 | Train loss: 0.3410 | Test loss: 0.1686
# Epoch 170 | Train loss: 0.3398 | Test loss: 0.1672
# Epoch 175 | Train loss: 0.3344 | Test loss: 0.1634
# Epoch 180 | Train loss: 0.2841 | Test loss: 0.1270
# Epoch 185 | Train loss: 0.4066 | Test loss: 0.2607
# Epoch 190 | Train loss: 0.1717 | Test loss: 0.1560
# Epoch 195 | Train loss: 0.3684 | Test loss: 0.1692
# Epoch 200 | Train loss: 0.1895 | Test loss: 0.1308
# Epoch 205 | Train loss: 0.1806 | Test loss: 0.1429
# Epoch 210 | Train loss: 0.1848 | Test loss: 0.1287
# Epoch 215 | Train loss: 0.1809 | Test loss: 0.1324
# Epoch 220 | Train loss: 0.1695 | Test loss: 0.1253
# Epoch 225 | Train loss: 0.1683 | Test loss: 0.1077
# Epoch 230 | Train loss: 0.1587 | Test loss: 0.0998
# Epoch 235 | Train loss: 0.1575 | Test loss: 0.0959
# Epoch 240 | Train loss: 0.1575 | Test loss: 0.0956
# Epoch 245 | Train loss: 0.1567 | Test loss: 0.0963
# Epoch 250 | Train loss: 0.1559 | Test loss: 0.0950
# Epoch 255 | Train loss: 0.1558 | Test loss: 0.0931
# Epoch 260 | Train loss: 0.1559 | Test loss: 0.0916
# Epoch 265 | Train loss: 0.1558 | Test loss: 0.0909
# Epoch 270 | Train loss: 0.1557 | Test loss: 0.0911
# Epoch 275 | Train loss: 0.1556 | Test loss: 0.0916
# Epoch 280 | Train loss: 0.1555 | Test loss: 0.0921
# Epoch 285 | Train loss: 0.1555 | Test loss: 0.0926
# Epoch 290 | Train loss: 0.1555 | Test loss: 0.0928
# Epoch 295 | Train loss: 0.1554 | Test loss: 0.0929
# Epoch 300 | Train loss: 0.1554 | Test loss: 0.0928
# Epoch 305 | Train loss: 0.1554 | Test loss: 0.0928
# Epoch 310 | Train loss: 0.1554 | Test loss: 0.0928
# Epoch 315 | Train loss: 0.1554 | Test loss: 0.0927
# Epoch 320 | Train loss: 0.1553 | Test loss: 0.0927
# Epoch 325 | Train loss: 0.1553 | Test loss: 0.0926
# Epoch 330 | Train loss: 0.1553 | Test loss: 0.0926
# Epoch 335 | Train loss: 0.1553 | Test loss: 0.0925
# Epoch 340 | Train loss: 0.1553 | Test loss: 0.0925
# Epoch 345 | Train loss: 0.1552 | Test loss: 0.0925
# Epoch 350 | Train loss: 0.1552 | Test loss: 0.0925
# Epoch 355 | Train loss: 0.1552 | Test loss: 0.0925
# Epoch 360 | Train loss: 0.1552 | Test loss: 0.0924
# Epoch 365 | Train loss: 0.1552 | Test loss: 0.0924
# Epoch 370 | Train loss: 0.1551 | Test loss: 0.0924
# Epoch 375 | Train loss: 0.1551 | Test loss: 0.0924
# Epoch 380 | Train loss: 0.1551 | Test loss: 0.0924
# Epoch 385 | Train loss: 0.1551 | Test loss: 0.0924
# Epoch 390 | Train loss: 0.1551 | Test loss: 0.0924
# Epoch 395 | Train loss: 0.1551 | Test loss: 0.0924
# Epoch 400 | Train loss: 0.1550 | Test loss: 0.0924
# Epoch 405 | Train loss: 0.1550 | Test loss: 0.0923
# Epoch 410 | Train loss: 0.1550 | Test loss: 0.0923
# Epoch 415 | Train loss: 0.1550 | Test loss: 0.0923
# Epoch 420 | Train loss: 0.1550 | Test loss: 0.0923
# Epoch 425 | Train loss: 0.1550 | Test loss: 0.0923
# Epoch 430 | Train loss: 0.1550 | Test loss: 0.0923
# Epoch 435 | Train loss: 0.1549 | Test loss: 0.0923
# Epoch 440 | Train loss: 0.1549 | Test loss: 0.0923
# Epoch 445 | Train loss: 0.1549 | Test loss: 0.0923
# Epoch 450 | Train loss: 0.1549 | Test loss: 0.0923
# Epoch 455 | Train loss: 0.1549 | Test loss: 0.0923
# Epoch 460 | Train loss: 0.1549 | Test loss: 0.0923
# Epoch 465 | Train loss: 0.1549 | Test loss: 0.0923
# Epoch 470 | Train loss: 0.1548 | Test loss: 0.0923
# Epoch 475 | Train loss: 0.1548 | Test loss: 0.0923
# Epoch 480 | Train loss: 0.1548 | Test loss: 0.0922
# Epoch 485 | Train loss: 0.1548 | Test loss: 0.0922
# Epoch 490 | Train loss: 0.1548 | Test loss: 0.0922
# Epoch 495 | Train loss: 0.1548 | Test loss: 0.0922

# %% [markdown]
# ## Visualization of Results

# %%
# Plot predictions vs targets in 3d
with torch.no_grad():
    test_pred_scaled = model(X_test_scaled).squeeze()
    test_pred = torch.from_numpy(y_scaler.inverse_transform(test_pred_scaled.numpy().reshape(-1, 1))).float().squeeze()
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(X_test[:, 0], X_test[:, 1], test_pred, c="blue", alpha=0.4, label="Predictions")
    ax.scatter(X_test[:, 0], X_test[:, 1], y_test, c="red", marker="x", alpha=0.6, label="Targets")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_title("Predictions vs Targets")
    ax.legend()
    plt.show()
